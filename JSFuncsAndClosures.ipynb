# %% [markdown]
# <a href="https://colab.research.google.com/github/rdlaidlaw/it612/blob/main/JSFuncsAndClosures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
#
# const addTax = (price, rate) => price + rate;
# console.log(addTax(10, 2));
# console.log(addTax(5, 1));
#
# console.log("");
#
# function createBurner(secret, limit) {
#   function secretFunc() {
#     if (limit === 0) {
#       return "Limit reached";
#     }
#     limit -= 1;
#     return secret;
#   }
#   return secretFunc;
# }
#
# let mySecret = createBurner("secret", 2);
# console.log(mySecret())
# console.log(mySecret())
# console.log(mySecret())
#
# console.log("");
#
# const obj = {
#   x: "x",
#   y: ["a", "b", "c"],
#   z: 5
# }
#
# let stringVersion = JSON.stringify(obj)
# console.log(stringVersion);
# let parsedVersion = JSON.parse(stringVersion);
# console.log(parsedVersion);
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# 12
# 6
#
# secret
# secret
# Limit reached
#
# {"x":"x","y":["a","b","c"],"z":5}
# { x: 'x', y: [ 'a', 'b', 'c' ], z: 5 }
